# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Student_Marksheet_1639650402.csv")

# %% [markdown]
# ## Display All Data Present in dataset

# %%
df
# Out:
#      Student Name  Subject-1   Subject-2  Subject-3  Subject-4  Subject-5  \
# 0       Student 1          29         76         26        100         87
# 1       Student 2          14         71         61         39         41
# 2       Student 3          26         62         60         64         75
# 3       Student 4          69         63         66         11         10
# 4       Student 5          35         42         17         16         90
# 5       Student 6          21         66         51         31         70
# 6       Student 7          38         16         96         48         49
# 7       Student 8          40         53         11         12         53
# 8       Student 9          24          5         30         12         81
# 9      Student 10          71         61         90         88         66
# 10     Student 11          48         24          9          9         48
# 11     Student 12          33          8         37         78         15
# ...

# %% [markdown]
# ## Information about (Columns,Rows,Data types)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student Name   51 non-null     object
#  1   Subject-1      51 non-null     int64
#  2   Subject-2      51 non-null     int64
#  3   Subject-3      51 non-null     int64
#  4   Subject-4      51 non-null     int64
#  5   Subject-5      51 non-null     int64
#  6   Subject-6      51 non-null     int64
#  7   Subject-7      51 non-null     int64
#  8   Student Total  50 non-null     float64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 3.7+ KB

# %% [markdown]
# ## Statistical Information Of Dataset

# %%
df.describe()
# Out:
#         Subject-1     Subject-2    Subject-3    Subject-4    Subject-5  \
# count    51.000000    51.000000    51.000000    51.000000    51.000000
# mean     92.235294    80.588235    93.529412    99.764706   101.058824
# std     323.720595   283.391544   328.500067   350.290313   354.553094
# min       2.000000     1.000000     3.000000     4.000000    10.000000
# 25%      30.000000    14.000000    26.500000    25.500000    30.500000
# 50%      47.000000    41.000000    51.000000    59.000000    55.000000
# 75%      68.000000    68.000000    70.000000    75.000000    73.500000
# max    2352.000000  2055.000000  2385.000000  2544.000000  2577.000000
#
#          Subject-6    Subject-7  Student Total
# count    51.000000    51.000000       50.00000
# mean    108.901961    88.431373      338.90000
# std     382.270441   310.647469       85.61524
# min       0.000000     1.000000      114.00000
# 25%      35.000000    25.000000      276.75000
# ...

# %% [markdown]
# ## Display Column Names in Dataset

# %%
df.columns
# Out:
# Index(['Student Name', 'Subject-1 ', 'Subject-2', 'Subject-3', 'Subject-4',
#        'Subject-5', 'Subject-6', 'Subject-7', 'Student Total'],
#       dtype='object')

# %% [markdown]
# ## Displays column values (Student Name)

# %%
df['Student Name']
# Out:
# 0         Student 1
# 1         Student 2
# 2         Student 3
# 3         Student 4
# 4         Student 5
# 5         Student 6
# 6         Student 7
# 7         Student 8
# 8         Student 9
# 9        Student 10
# 10       Student 11
# 11       Student 12
# 12       Student 13
# 13       Student 14
# 14       Student 15
# 15       Student 16
# 16       Student 17
# 17       Student 18
# 18       Student 19
# 19       Student 20
# 20       Student 21
# 21       Student 22
# 22       Student 23
# 23       Student 24
# 24       Student 25
# 25       Student 26
# 26       Student 27
# 27       Student 28
# 28       Student 29
# 29       Student 30
# 30       Student 31
# 31       Student 32
# 32       Student 33
# 33       Student 34
# 34       Student 35
# 35       Student 36
# 36       Student 37
# 37       Student 38
# 38       Student 39
# 39       Student 40
# 40       Student 41
# 41       Student 42
# 42       Student 43
# 43       Student 44
# 44       Student 45
# ...

# %%
df['Student Name']
# Out:
# 0         Student 1
# 1         Student 2
# 2         Student 3
# 3         Student 4
# 4         Student 5
# 5         Student 6
# 6         Student 7
# 7         Student 8
# 8         Student 9
# 9        Student 10
# 10       Student 11
# 11       Student 12
# 12       Student 13
# 13       Student 14
# 14       Student 15
# 15       Student 16
# 16       Student 17
# 17       Student 18
# 18       Student 19
# 19       Student 20
# 20       Student 21
# 21       Student 22
# 22       Student 23
# 23       Student 24
# 24       Student 25
# 25       Student 26
# 26       Student 27
# 27       Student 28
# 28       Student 29
# 29       Student 30
# 30       Student 31
# 31       Student 32
# 32       Student 33
# 33       Student 34
# 34       Student 35
# 35       Student 36
# 36       Student 37
# 37       Student 38
# 38       Student 39
# 39       Student 40
# 40       Student 41
# 41       Student 42
# 42       Student 43
# 43       Student 44
# 44       Student 45
# ...

# %% [markdown]
# ## Displays Unique values

# %%
df['Student Name'].unique()
# Out:
# array(['Student 1', 'Student 2', 'Student 3', 'Student 4', 'Student 5',
#        'Student 6', 'Student 7', 'Student 8', 'Student 9', 'Student 10',
#        'Student 11', 'Student 12', 'Student 13', 'Student 14',
#        'Student 15', 'Student 16', 'Student 17', 'Student 18',
#        'Student 19', 'Student 20', 'Student 21', 'Student 22',
#        'Student 23', 'Student 24', 'Student 25', 'Student 26',
#        'Student 27', 'Student 28', 'Student 29', 'Student 30',
#        'Student 31', 'Student 32', 'Student 33', 'Student 34',
#        'Student 35', 'Student 36', 'Student 37', 'Student 38',
#        'Student 39', 'Student 40', 'Student 41', 'Student 42',
#        'Student 43', 'Student 44', 'Student 45', 'Student 46',
#        'Student 47', 'Student 48', 'Student 49', 'Student 50',
#        'Subject total'], dtype=object)

# %% [markdown]
# ## Displays unique values in column (Student Total)

# %%
df['Student Total'].unique()
# Out:
# array([337., 319., 366., 282., 241., 326., 363., 275., 199., 561., 264.,
#        314., 408., 187., 378., 420., 225., 356., 274., 421., 343., 359.,
#        320., 362., 431., 357., 349., 387., 415., 332., 404., 216., 316.,
#        386., 375., 395., 391., 269., 211., 291., 114., 416., 265., 501.,
#        447., 379., 200.,  nan])

# %% [markdown]
# ## Displays count of unique values

# %%
df['Student Total'].nunique()
# Out:
# 47

# %% [markdown]
# ## Displays record of student where Subject-2 marks==66

# %%
df[df['Subject-2']== 66]
# Out:
#   Student Name  Subject-1   Subject-2  Subject-3  Subject-4  Subject-5  \
# 5    Student 6          21         66         51         31         70
#
#    Subject-6  Subject-7  Student Total
# 5          6         81          326.0

# %% [markdown]
# ## Displays record of students where subject-3 marks >= 80

# %%
df[df['Subject-3'] >=80]
# Out:
#      Student Name  Subject-1   Subject-2  Subject-3  Subject-4  Subject-5  \
# 6       Student 7          38         16         96         48         49
# 9      Student 10          71         61         90         88         66
# 15     Student 16          43         76         89         72         32
# 18     Student 19          19         74         98         19         52
# 28     Student 29          65         76         96         63         41
# 44     Student 45          98          1         99         72         83
# 46     Student 47          82         12         91         90         79
# 50  Subject total        2352       2055       2385       2544       2577
#
#     Subject-6  Subject-7  Student Total
# 6          77         39          363.0
# 9          88         97          561.0
# 15         34         74          420.0
# 18          5          7          274.0
# 28          3         77          421.0
# 44         58          5          416.0
# ...

# %%
df[df['Subject-4'] >= 60].min()
#df[df['Subject-4'] >= 60].max()
# Out:
# Student Name     Student 1
# Subject-1                2
# Subject-2                1
# Subject-3                3
# Subject-4               60
# Subject-5               10
# Subject-6                3
# Subject-7                5
# Student Total        314.0
# dtype: object

# %% [markdown]
# ## Displays Record where Student Total ==420

# %%
df[df['Student Total'] == 420]
# Out:
#    Student Name  Subject-1   Subject-2  Subject-3  Subject-4  Subject-5  \
# 15   Student 16          43         76         89         72         32
#
#     Subject-6  Subject-7  Student Total
# 15         34         74          420.0

# %% [markdown]
# ## length of Record where Student Total ==420

# %%
len(df[df['Student Total']==420])
# Out:
# 1

# %% [markdown]
# #### 1) .loc(label based indexing) uses labels while .iloc(integer position based indexing) uses integer position to access data in DataFrame
# #### 2) Percentage : value out of 100
# #### 3) Percentile : the rank compares to others

# %%
dir(df['Student Total'])
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...
