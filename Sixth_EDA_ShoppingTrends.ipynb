# %% [raw]
# By Apoorva Khare

# %% [markdown]
# https://www.kaggle.com/datasets/iamsouravbanerjee/customer-shopping-trends-dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load and read the dataset
df = pd.read_csv("shopping_trends.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.describe() #statistical description
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isna().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
# histogram plot of age vs frequency
df['Age'].plot(kind = "hist", edgecolor = "black")
plt.xlabel("Age")
plt.title("Age vs Frequency")
plt.show()

# %%
# bar plot of gender vs count
df["Gender"].value_counts().plot(kind = 'bar', color = ['blue', 'orange'])
plt.title("Gender vs count")
plt.grid(alpha = 0.2)
plt.show()

# %%
# Average of Purchase amount by category
df.groupby("Category")['Purchase Amount (USD)'].mean().sort_values(ascending = False).tail(3)
# Out:
# Category
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
# Review Rating in Descending order
df.sort_values("Review Rating", ascending = False, inplace = True)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2393         2394   58    Male          Socks     Clothing
# 2405         2406   69    Male          Jeans     Clothing
# 600           601   22    Male            Hat  Accessories
# 3467         3468   18  Female          Scarf  Accessories
# 507           508   65    Male         Shorts     Clothing
# ...           ...  ...     ...            ...          ...
# 2380         2381   41    Male          Scarf  Accessories
# 133           134   52    Male        Sweater     Clothing
# 2724         2725   52  Female       Sneakers     Footwear
# 1889         1890   59    Male          Skirt     Clothing
# 3836         3837   62  Female          Skirt     Clothing
#
#       Purchase Amount (USD)        Location Size     Color  Season  \
# 2393                     97       Louisiana    M     Brown  Winter
# 2405                     97      California   XL    Silver    Fall
# ...

# %%
# Count of Subscription Status
df['Subscription Status'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%' )
plt.title("Pie chart of Subscription Status Count")
plt.show()

# %%
df.Color.unique()
# Out:
# array(['Brown', 'Silver', 'Charcoal', 'Magenta', 'Black', 'Turquoise',
#        'Gold', 'Olive', 'Red', 'Yellow', 'Maroon', 'Purple', 'Indigo',
#        'Cyan', 'Peach', 'White', 'Pink', 'Gray', 'Blue', 'Orange',
#        'Violet', 'Green', 'Lavender', 'Teal', 'Beige'], dtype=object)

# %%
# plotting a box plot for Purchased Amount by Frequency of Purchases
plt.figure(figsize= (10, 20))
df.boxplot(column ='Purchase Amount (USD)',by = "Frequency of Purchases")
plt.title("")
plt.show()

# %%
# Count of Payment Method
# Count the values
counts = df['Payment Method'].value_counts()

# Generate distinct colors
num_bars = len(counts)
colors = plt.cm.tab20(np.linspace(0, 1, num_bars))

# Create a plot and save the axes object
ax = counts.plot(kind='bar', edgecolor='black', color=colors)

# Add title and labels (optional)
plt.ylabel('Count')
plt.title('---')

# Annotate each bar with its value
for i, value in enumerate(counts):
    ax.text(i, value + 1, str(value), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# pivot table for average of Purchased Amount according to its location and item purchased
pd.pivot_table(df, values = 'Purchase Amount (USD)', index = "Location", columns = "Item Purchased", aggfunc = "mean").head(10)
# Out:
# Item Purchased  Backpack       Belt     Blouse      Boots       Coat  \
# Location
# Alabama            74.00  26.500000  52.000000  73.666667  54.500000
# Alaska             74.60  76.750000  67.500000  56.000000  45.500000
# Arizona            48.60  84.500000  61.000000        NaN  65.333333
# Arkansas           90.00  55.000000  66.000000  50.000000  54.250000
# California         57.40  61.666667  39.500000  62.500000  55.000000
# Colorado           57.00  68.500000  55.000000        NaN  46.000000
# Connecticut        60.00  47.666667  67.400000  64.250000  44.500000
# Delaware           33.00  41.500000  42.200000  44.500000  57.500000
# Florida            59.00  94.000000  31.000000  51.500000  51.166667
# Georgia            44.75  62.000000  64.857143  85.000000  93.000000
#
# Item Purchased      Dress     Gloves    Handbag        Hat     Hoodie  ...  \
# Location                                                               ...
# ...

# %%
# Average of Purchased Amount based on different size
df.groupby("Size")["Purchase Amount (USD)"].mean()
# Out:
# Size
# L     58.563153
# M     59.924217
# S     61.037707
# XL    60.090909
# Name: Purchase Amount (USD), dtype: float64

# %%
#
df.groupby("Payment Method")["Purchase Amount (USD)"].sum().sort_values(ascending = False).plot(kind = "line")
plt.title("Sum of Purchased Method in descending order based on Payement type ")
plt.show()

# %%
# Median of Previous Purchases groupedby Frequency of Purchases
df.groupby("Frequency of Purchases")['Previous Purchases'].median()
# Out:
# Frequency of Purchases
# Annually          24.0
# Bi-Weekly         24.0
# Every 3 Months    24.0
# Fortnightly       26.0
# Monthly           25.0
# Quarterly         28.0
# Weekly            26.0
# Name: Previous Purchases, dtype: float64

# %%
# Count of Season
df['Season'].value_counts().plot(kind = 'bar')
plt.title("Season Count")
plt.grid()
plt.show()

# %%
# which category make the largest sales
df['Category'].unique()
# Out:
# array(['Clothing', 'Accessories', 'Footwear', 'Outerwear'], dtype=object)

# %%
df.groupby("Category")["Purchase Amount (USD)"].sum().plot(kind = "line")
plt.title("Line plot for Purchased Amount Groupedby Category")
plt.show()

# %%
df.groupby("Category")["Purchase Amount (USD)"].sum().reset_index()
# Out:
#       Category  Purchase Amount (USD)
# 0  Accessories                  74200
# 1     Clothing                 104264
# 2     Footwear                  36093
# 3    Outerwear                  18524

# %%
df.groupby("Category")["Purchase Amount (USD)"].sum().reset_index().plot(
    kind="scatter",
    x="Category",
    y="Purchase Amount (USD)",
    marker = "D"
)
plt.show()
